# %% [markdown]
# <a href="https://colab.research.google.com/github/David2511-un/Flooding-information/blob/main/Tema_Pclp3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
flood = pd.read_csv("/content/FlooddataMasterListrev.csv")

# %%
print(flood.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4541 entries, 0 to 4540
# Data columns (total 36 columns):
#  #   Column                                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                                --------------  -----
#  0   Register #                                                                                                            4213 non-null   float64
#  1   Annual DFO # (discontinued)                                                                                           3517 non-null   object
#  2   Glide #                                                                                                               4218 non-null   object
#  3   Country                                                                                                               4207 non-null   object
# ...

# %%
print(flood.head())
# Out:
#    Register # Annual DFO # (discontinued)             Glide #    Country  \
# 0      4214.0                         NaN  FL-2014-000163-COL   Columbia
# 1      4213.0                         NaN                   0        USA
# 2      4212.0                         NaN                   0     Brazil
# 3      4211.0                         NaN                   0   Bulgaria
# 4      4210.0                         NaN                   0  Palestine
#
#     Other  Nations   Affected  \
# 0       0      NaN        NaN
# 1       0      NaN        NaN
# 2       0      NaN        NaN
# 3  Greece      NaN        NaN
# 4       0      NaN        NaN
#
#   Detailed Locations (click on active links to access inundation extents)  \
# 0                                              Chocó
# 1  Bay Area, and Sacramento, north coastal Califo...
# 2                                  Eastern Sao Paulo
# 3  Northern Greece and along the country's northe...
# ...

# %%
flood_info = flood[["Country", "Duration in Days", "Dead", "Affected sq km", "Magnitude (M)**", "Main cause", "Severity *",
                    "Displaced", "Total annual floods M>6", "Total annual floods M>4"]]

# %%
print(flood_info.head())
# Out:
#      Country  Duration in Days  Dead  Affected sq km  Magnitude (M)**  \
# 0   Columbia              44.0  44.0       406009.51              7.3
# 1        USA               4.0   3.0        50235.67              5.3
# 2     Brazil               5.0   0.0       199807.20              6.0
# 3   Bulgaria              11.0  40.0       147616.57              6.4
# 4  Palestine              10.0   0.0         2861.66              4.6
#
#          Main cause  Severity *  Displaced  Total annual floods M>6  \
# 0        Heavy Rain         1.0        0.0                     98.0
# 1   Torrential Rain         1.0        0.0                     97.0
# 2  Torrrential Rain         1.0        0.0                     97.0
# 3        Heavy Rain         1.5     1000.0                     97.0
# 4   Torrential Rain         1.5      300.0                     96.0
#
#    Total annual floods M>4
# 0                    199.0
# 1                    198.0
# 2                    197.0
# ...

# %%
print(flood_info.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4541 entries, 0 to 4540
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  4207 non-null   object
#  1   Duration in Days         4207 non-null   float64
#  2   Dead                     4207 non-null   float64
#  3   Affected sq km           4207 non-null   float64
#  4   Magnitude (M)**          4208 non-null   float64
#  5   Main cause               4207 non-null   object
#  6   Severity *               4207 non-null   float64
#  7   Displaced                4207 non-null   float64
#  8   Total annual floods M>6  4210 non-null   float64
#  9   Total annual floods M>4  4210 non-null   float64
# dtypes: float64(8), object(2)
# memory usage: 354.9+ KB
# None

# %%
print(flood_info.describe())
# Out:
#        Duration in Days           Dead  Affected sq km  Magnitude (M)**  \
# count       4207.000000    4207.000000    4.207000e+03      4208.000000
# mean          11.077490     156.310910    1.029468e+05         5.299049
# std           16.270075    3633.050959    2.238610e+05         1.109618
# min            1.000000       0.000000    1.195650e+01         0.000000
# 25%            3.000000       0.000000    8.178225e+03         4.600000
# 50%            6.000000       5.000000    3.087756e+04         5.300000
# 75%           12.000000      24.000000    1.003976e+05         6.100000
# max          419.000000  160000.000000    4.814281e+06         8.500000
#
#         Severity *     Displaced  Total annual floods M>6  \
# count  4207.000000  4.207000e+03              4210.000000
# mean      1.210601  1.505215e+05                23.883848
# std       0.379079  1.267716e+06                17.996728
# min       1.000000  0.000000e+00                 0.000000
# ...
